# %% [markdown]
# # Trabajo integrador - Parte 2

# %% [markdown]
# # Aprendizaje Supervisado
#
# **Nombre**: Javier Cambiasso

# %% [markdown]
# ## Problema de regresión

# %% [markdown]
# Para la creación de los datasets y la manipulación de los mismos vamos a trabajar directamente con dos módulos includios en la carpeta utils.
#
# En esta podemos encontrar:
#  - generate_data: Esta función wrappea el método de _make_regression_ de scikit learn para devolver un dataframe con un problema de regresión basado en sus parámetros.
#  - generate_outliers: Esta función genera outliers livianos y pesados en función de los parámetros que le demos de entrada.

# %%
from utils.data_generation import generate_dataset
from utils.data_manipulation import generate_outliers

# %% [markdown]
# ### Ejemplo de uso

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
## Vamos a crear un dataset primero.

data = generate_dataset(
    n_samples=1000,
    n_features=5,
    n_informative=2,
    n_targets=1,
    noise=0,
    output='dataframe'
)

## esto nos genera un dataset que contiene 5 features, 2 de los cuales son informativos, y 1 target.

data.head()
# Out:
#          x0        x1        x2        x3        x4     target
# 0  0.738249  0.172571  0.674427  0.532763  0.590892  58.589059
# 1  0.994491  0.353090  0.169338 -0.801130  0.580041  89.449580
# 2  0.238216  0.369652  0.528941 -0.148146 -0.350361  46.300273
# 3  0.884936 -1.354189 -0.549422  0.060664  0.690255 -65.977780
# 4 -0.729836 -0.362630 -0.032134 -0.402267  0.153284 -74.676348

# %%
## vamos a visualizar estas variables
## creamos una figura de matplotlib que contenga 5 subplots, uno por cada feature:

fig, axes = plt.subplots(1, 5, figsize=(20, 5))

## Creamos un loop para iterar sobre cada feature y graficar la regresión lineal entre cada feature y el target:

for i, feature in enumerate(data.columns[:-1]):
    sns.regplot(x=feature,
                y='target',
                data=data,
                ax=axes[i],
                scatter_kws={'alpha': 0.4},
                line_kws={'color': 'red'},
                ci=95)

# %% [markdown]
# Ahora agregamos _outliers_ a un nuevo dataset

# %%
data = generate_dataset(
    n_samples=1000,
    n_features=1,
    n_informative=1,
    n_targets=1,
    noise=0,
    output='dataframe'
)

# %%
do1 = generate_outliers(
    df=data,
    columns=['x0'],
    percentage=0.01,
    extreme_outliers=False,
    only_tails=False,
)
do2 = generate_outliers(
    df=data,
    columns=['x0'],
    percentage=0.01,
    extreme_outliers=False,
    only_tails=True,
    two_tailed=True,
)
do3 = generate_outliers(
    df=data,
    columns=['x0'],
    percentage=0.01,
    extreme_outliers=False,
    only_tails=True,
    two_tailed=False,
)

# %%
## vamos a visualizar estas los distintos datasets

fig, axes = plt.subplots(1, 4, figsize=(20, 5))

sns.regplot(x='x0',
            y='target',
            data=data,
            ax=axes[0],
            scatter_kws={'alpha': 0.4},
            line_kws={'color': 'red'},
            ci=95)
axes[0].set_title('Original')

sns.regplot(x='x0',
            y='target',
            data=do1,
            ax=axes[1],
            scatter_kws={'alpha': 0.4},
            line_kws={'color': 'red'},
            ci=95)
axes[1].set_title('Outliers')

sns.regplot(x='x0',
            y='target',
            data=do2,
            ax=axes[2],
            scatter_kws={'alpha': 0.4},
            line_kws={'color': 'red'},
            ci=95)
axes[2].set_title('Outliers (two-tailed)')

sns.regplot(x='x0',
            y='target',
            data=do3,
            ax=axes[3],
            scatter_kws={'alpha': 0.4},
            line_kws={'color': 'red'},
            ci=95)
axes[3].set_title('Outliers (one-tailed)')
# Out:
# Text(0.5, 1.0, 'Outliers (one-tailed)')

# %%
## y si lo queremos con mucho mas outliers?

doe = generate_outliers(
    df=data,
    columns=['x0'],
    percentage=0.1,
    extreme_outliers=True)

## vamos a visualizar este caso

fig, axes = plt.subplots(1, 2, figsize=(20, 5))

sns.regplot(x='x0',
            y='target',
            data=data,
            ax=axes[0],
            scatter_kws={'alpha': 0.4},
            line_kws={'color': 'red'},
            ci=95)
axes[0].set_title('Original')

sns.regplot(x='x0',
            y='target',
            data=doe,
            ax=axes[1],
            scatter_kws={'alpha': 0.4},
            line_kws={'color': 'red'},
            ci=95)
axes[1].set_title('Outliers')
# Out:
# Text(0.5, 1.0, 'Outliers')

# %% [markdown]
# ### Ejercicio 4

# %% [markdown]
# Utilizando la funcion `generate_data` generar un problema de regresión multivariada en el cual cuente con N variables informativas y M variables no informativas.
#
# Ejemplo:
# ```python
# data = generate_dataset(n_samples=1000,
#                     n_features=10,
#                     n_informative=5,
#                     n_targets=1,
#                     noise=20.0,
#                     random_state=42,
#                     output='dataframe')
#
# ```
#
# Dado un valor de _noise_ fijo, sin fijar _random_state_ (para poder asegurarnos
# que los datos que generamos son distintos) realizaremos 100 simulaciones de este dataset.
#
# En la simulación deberemos generar el dataset, hacer una división de train-test, ajustar
# un modelo de regresión lineal multivariada y validar el mismo.
#
# En cada iteración de esta simulación debemos guardar:
#
# - Los coeficientes de la regresión.
# - El RMSE de train y test.
# - El MAE de train y test.
#
#
# > Qué pasa con los coeficientes de las variables no informativas? La regresión se ve afectada por estas variables?
# > ***HINT:*** Utilice las distribuciones de los coeficientes para analizar y test de hipótesis para sacar conclusiones.

# %%
#Juego un poquito
import numpy as np
import pandas as pd
from tqdm import tqdm
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error

data = generate_dataset(
    n_samples=1000,
    n_features=5,
    n_informative=2,
    n_targets=1,
    noise=10,
    bias=5,
    output='dataframe',
    random_state=10
)

X_train, X_test, Y_train, Y_test = train_test_split(data.drop('target',axis=1),data['target'],random_state=20,train_size=0.8)
model = LinearRegression()
model.fit(X_train,Y_train)
Y_pred = model.predict(X_test)
RMSE = mean_squared_error(Y_test,Y_pred)
MAE = mean_absolute_error(Y_test, Y_pred)
results = {'Coefs':model.coef_,'RMSE':RMSE,'MAE':MAE}
print(results)

X_test['Predict'] = np.array(model.coef_) @ X_test.values.T
X_test['Real'] = Y_test
sns.relplot(data=X_test,
            x='Predict',
            y='Real',
            kind='scatter')
# Out:
# {'Coefs': array([53.47327571, 94.99067527,  0.33732342, -0.15341224,  0.53450716]), 'RMSE': 85.81405050208515, 'MAE': 7.475620935417806}
# g:\Mi unidad\Facultad\Inteligencia Artificial\intro_ia\.venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# g:\Mi unidad\Facultad\Inteligencia Artificial\intro_ia\.venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# g:\Mi unidad\Facultad\Inteligencia Artificial\intro_ia\.venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# g:\Mi unidad\Facultad\Inteligencia Artificial\intro_ia\.venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# g:\Mi unidad\Facultad\Inteligencia Artificial\intro_ia\.venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# g:\Mi unidad\Facultad\Inteligencia Artificial\intro_ia\.venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# g:\Mi unidad\Facultad\Inteligencia Artificial\intro_ia\.venv\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
## Parámetros de la simulación
n_exp = 100
n_samples = 1000
n_features = 10
n_informative = 2
n_targets = 1

noise = np.linspace(0, 100, 10)
bias = np.linspace(0, 100, 10)

#Defino la funcion de simulación de regresión y pruebo el dataframe de salida.
def LinearRegressionSimul(noise = 0, bias = 0, n_samples = 1000, n_features = 10,n_informative = 2, n_targets = 1,random_state = None):
    data = generate_dataset(
    n_samples=n_samples,
    n_features=n_features,
    n_informative=n_informative,
    n_targets=n_targets,
    noise=noise,
    bias=bias,
    output='dataframe',
    random_state=random_state
    )
    X_train, X_test, Y_train, Y_test = train_test_split(data.drop('target',axis=1),data['target'],random_state=20,train_size=0.8)
    model = LinearRegression()
    model.fit(X_train,Y_train)
    y_pred = model.predict(X_test)
    RMSE_test = mean_squared_error(Y_test,y_pred)
    MAE_test = mean_absolute_error(Y_test, y_pred)
    y_pred = model.predict(X_train)
    RMSE_train = mean_squared_error(Y_train,y_pred)
    MAE_train = mean_absolute_error(Y_train, y_pred)
    return np.array(model.coef_), np.array([RMSE_test,MAE_test,RMSE_train,MAE_train,noise])

coefs_l = []
metrics_l = []
for i in range(10):
    coef, metrics = LinearRegressionSimul()
    coefs_l.append(coef)
    metrics_l.append(metrics)

coefs_l = np.vstack(coefs_l)
metrics_l = np.vstack(metrics_l)
df = pd.DataFrame(data=coefs_l,columns=[f'x{i}' for i in range(coefs_l.shape[1])])
df['RMSE test'] = metrics_l[:,0]
df['MAE test'] = metrics_l[:,1]
df['RMSE train'] = metrics_l[:,2]
df['MAE train'] = metrics_l[:,3]
df['Noise'] = metrics_l[:,4]
df
# Out:
#           x0         x1            x2            x3            x4  \
# 0   7.337008  95.340141 -5.329071e-15 -4.973799e-14  1.509903e-14
# 1  33.951004  54.720108  0.000000e+00 -3.197442e-14  0.000000e+00
# 2  98.642861  83.355417  1.154632e-14 -6.927792e-14 -2.309264e-14
# 3  55.600348  48.711199  5.329071e-15 -1.421085e-14 -1.154632e-14
# 4  87.158088  91.872455 -9.547918e-15 -2.486900e-14 -1.421085e-14
# 5   1.163723  42.046306 -2.842171e-14  3.330669e-14  1.065814e-14
# 6  91.594498  66.299129 -1.563194e-13  1.145750e-13  1.731948e-13
# 7  25.546079   7.032853  6.661338e-16 -1.554312e-15 -1.110223e-14
# 8   9.082513  46.561260  3.552714e-15 -1.065814e-14  3.552714e-15
# 9  58.266427  66.168383  1.421085e-14 -1.065814e-14 -3.641532e-14
#
#              x5            x6            x7            x8            x9  \
# 0  1.136868e-13 -4.618528e-14 -1.421085e-14 -2.131628e-14 -4.440892e-15
# 1 -4.263256e-14  2.198242e-14  3.197442e-14 -5.329071e-14  1.421085e-14
# 2 -4.973799e-14  0.000000e+00 -6.394885e-14 -7.105427e-15  3.907985e-14
# 3 -1.421085e-14  1.776357e-15  0.000000e+00 -1.776357e-14 -1.598721e-14
# 4  0.000000e+00 -3.019807e-14  1.953993e-14 -7.105427e-15 -7.105427e-15
# 5 -1.065814e-14  1.123546e-13  4.085621e-14  2.842171e-14 -2.131628e-14
# 6 -3.552714e-14 -7.949197e-14 -2.735590e-13 -5.606626e-14 -1.740830e-13
# 7  8.437695e-15 -1.332268e-14 -4.884981e-15 -1.643130e-14  1.976197e-14
# 8  1.598721e-14 -3.996803e-15 -1.421085e-14 -1.754152e-14 -8.881784e-15
# 9  5.329071e-15 -7.105427e-15  2.842171e-14 -8.881784e-16 -2.131628e-14
#
#       RMSE test      MAE test    RMSE train     MAE train  Noise
# 0  3.300462e-26  1.447775e-13  2.768507e-26  1.324816e-13    0.0
# 1  9.498544e-27  7.717410e-14  8.603662e-27  7.444627e-14    0.0
# 2  2.057079e-26  1.170687e-13  1.787499e-26  1.059507e-13    0.0
# 3  2.254248e-27  3.859670e-14  2.368670e-27  3.848647e-14    0.0
# 4  4.713630e-27  5.476161e-14  4.915092e-27  5.614838e-14    0.0
# 5  2.551690e-26  1.274446e-13  2.071009e-26  1.172164e-13    0.0
# 6  1.886732e-25  3.368889e-13  1.965278e-25  3.503152e-13    0.0
# 7  1.345632e-27  2.964975e-14  1.336307e-27  2.894982e-14    0.0
# 8  2.588244e-27  4.000106e-14  2.687031e-27  4.117292e-14    0.0
# 9  3.112892e-27  4.421630e-14  3.739632e-27  4.913885e-14    0.0

# %%
## Esqueleto de la simulación
coefs_l = []
metrics_l = []
for _ in tqdm(range(n_exp)):
    for b in bias:
        for n in noise:
            coef,metrics = LinearRegressionSimul(noise = n, bias = b, n_samples = 1000, n_features = 10,n_informative = 2, n_targets = 1)
            coefs_l.append(coef)
            metrics_l.append(metrics)

coefs_l = np.vstack(coefs_l)
metrics_l = np.vstack(metrics_l)
print(coefs_l.shape)
df = pd.DataFrame(data=coefs_l,columns=[f'x{i}' for i in range(coefs_l.shape[1])])
df['RMSE test'] = metrics_l[:,0]
df['MAE test'] = metrics_l[:,1]
df['RMSE train'] = metrics_l[:,2]
df['MAE train'] = metrics_l[:,3]
df['Noise'] = metrics_l[:,4]
df
# Out:
# 100%|██████████| 100/100 [00:37<00:00,  2.65it/s]
# (10000, 10)
#              x0          x1            x2            x3        x4  \
# 0     39.811268   15.869162 -1.021405e-14 -2.664535e-15  0.000000
# 1     35.415418   64.948069  9.855559e-01 -7.114880e-02 -0.377521
# 2     46.761953   17.786108  1.049678e-01 -2.909813e-01 -0.130648
# 3     80.101596   18.745003  9.401825e-01  1.082389e+00  0.903119
# 4     67.136714   72.355818  1.653727e+00 -6.254693e-01  2.875171
# ...         ...         ...           ...           ...       ...
# 9995  44.081933   55.279721 -1.830658e+00 -1.352661e+00 -1.410231
# 9996  92.968456   97.425838  1.463626e+00 -4.824450e+00  0.908251
# 9997  83.038962  102.713322  1.042629e-01  1.037952e+00  2.482910
# 9998  76.343285   90.284746 -4.677534e+00  2.212396e+00 -1.570089
# 9999  69.929377   18.345564  1.580048e+00 -2.614660e+00  0.704068
#
#                 x5            x6            x7            x8            x9  \
# 0     2.664535e-15 -1.154632e-14  5.329071e-15 -4.662937e-15 -3.552714e-15
# 1     3.658545e-01 -1.151379e-01 -1.431603e-02  5.444556e-01  2.590238e-01
# 2    -9.142550e-01 -1.481307e+00 -1.923000e-02  1.040688e+00 -1.053432e-02
# 3    -1.460352e+00  3.386955e-01 -1.665407e-01  4.666393e-01  1.504068e+00
# 4    -1.735871e+00  7.640946e-01 -8.248861e-01 -7.788005e-01 -3.867564e-01
# ...            ...           ...           ...           ...           ...
# 9995 -1.322186e+00  5.231867e-01 -2.667541e+00 -1.566222e-01 -6.211583e-01
# 9996 -1.176649e+00 -3.535081e-01 -3.007973e-01 -1.761864e+00  3.443069e+00
# 9997  3.778244e+00  2.175947e+00  1.227666e+00 -2.265588e+00  5.802672e+00
# 9998  2.142698e+00  4.125907e+00 -1.793857e+00  2.861797e+00 -3.440427e+00
# 9999 -1.101295e+00  5.015860e+00 -2.947366e+00  1.425249e+00 -3.007018e+00
#
#          RMSE test      MAE test    RMSE train     MAE train       Noise
# 0     5.672594e-28  1.893929e-14  5.392865e-28  1.824144e-14    0.000000
# 1     1.380961e+02  9.146124e+00  1.281645e+02  9.033997e+00   11.111111
# 2     4.887337e+02  1.752761e+01  5.055550e+02  1.776205e+01   22.222222
# 3     1.009319e+03  2.506457e+01  1.079971e+03  2.613670e+01   33.333333
# 4     1.854623e+03  3.464929e+01  2.002321e+03  3.597375e+01   44.444444
# ...            ...           ...           ...           ...         ...
# 9995  2.727214e+03  4.160895e+01  2.869835e+03  4.217542e+01   55.555556
# 9996  5.708159e+03  6.123967e+01  4.224312e+03  5.239406e+01   66.666667
# 9997  7.062666e+03  6.705118e+01  5.399406e+03  5.903633e+01   77.777778
# 9998  7.291404e+03  6.655857e+01  7.475057e+03  6.940651e+01   88.888889
# 9999  1.038259e+04  8.250024e+01  9.333540e+03  7.714103e+01  100.000000
#
# [10000 rows x 15 columns]

# %%
sns.relplot(data=df,
            x='Noise',
            y='RMSE test',
            kind='scatter')
# Out:
# g:\Mi unidad\Facultad\Inteligencia Artificial\intro_ia\.venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# g:\Mi unidad\Facultad\Inteligencia Artificial\intro_ia\.venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# g:\Mi unidad\Facultad\Inteligencia Artificial\intro_ia\.venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# g:\Mi unidad\Facultad\Inteligencia Artificial\intro_ia\.venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# g:\Mi unidad\Facultad\Inteligencia Artificial\intro_ia\.venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# g:\Mi unidad\Facultad\Inteligencia Artificial\intro_ia\.venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# g:\Mi unidad\Facultad\Inteligencia Artificial\intro_ia\.venv\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# A medida que crece el ruido, crecen los errores en general y los parámetros de features no informativos empiezan a tomar relevancia, mientras que en ruido bajo eran insignificantes a la salida.

# %%
sns.relplot(data=df,
            x='Noise',
            y='x2',
            kind='scatter')
# Out:
# g:\Mi unidad\Facultad\Inteligencia Artificial\intro_ia\.venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# g:\Mi unidad\Facultad\Inteligencia Artificial\intro_ia\.venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# g:\Mi unidad\Facultad\Inteligencia Artificial\intro_ia\.venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# g:\Mi unidad\Facultad\Inteligencia Artificial\intro_ia\.venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# g:\Mi unidad\Facultad\Inteligencia Artificial\intro_ia\.venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# g:\Mi unidad\Facultad\Inteligencia Artificial\intro_ia\.venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# g:\Mi unidad\Facultad\Inteligencia Artificial\intro_ia\.venv\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### Ejercicio 5

# %% [markdown]
# Utilizando la funcion `generate_outliers` generar puntos extremos dentro de los datos que generamos anteriormente. En este ejercicio dejar setteado `extreme_outliers` como `False` y observe como variando el porcentaje de los mismos la regresión comienza a afectarse.
#
# Pasos:
#
# 1. Generamos un dataset de regresion lineal simple (1 feature y 1 target value) con `noise` fijo en 0.5.
# 2. Generamos outliers fijando `extreme_outliers`.
# 2. Probar los distintos regresores a ver como se comportan frente a estos datasets anómalos.
# 3. Simular con multiples porcentajes de outliers (desde 1% hasta 10%). Qué pasa con los modelos?
#
# Los modelos a utilizar en este problema son:
#
#     - Regresion Lineal simple
#     - Regresion de Huber
#     - Regresión Ridge

# %%
from sklearn.linear_model import LinearRegression, HuberRegressor, RidgeCV

#Hago un overload de LinearRegressionSimul, agregando modelo linear como parametro y outliers
def LinearRegressionSimul(noise = 0, bias = 0, n_samples = 1000, n_features = 10,n_informative = 2, n_targets = 1,random_state = None, model = LinearRegression, outliers = 0):
    data = generate_dataset(
    n_samples=n_samples,
    n_features=n_features,
    n_informative=n_informative,
    n_targets=n_targets,
    noise=noise,
    bias=bias,
    output='dataframe',
    random_state=random_state
    )
    if outliers != 0: 
        data = generate_outliers(
        df=data,
        columns=['x0'],
        percentage=outliers,
        extreme_outliers=False) 
    X_train, X_test, Y_train, Y_test = train_test_split(data.drop('target',axis=1),data['target'],train_size=0.8,random_state=10)
    model = model()
    model.fit(X_train,Y_train)
    incercept = np.array(model.intercept_)
    Y_pred = model.predict(X_train)
    RMSE_train = mean_squared_error(Y_train,Y_pred)
    MAE_train = mean_absolute_error(Y_train, Y_pred)
    Y_pred = model.predict(X_test)
    RMSE_test = mean_squared_error(Y_test,Y_pred)
    MAE_test = mean_absolute_error(Y_test, Y_pred)
    return np.array(model.coef_), incercept, np.array([RMSE_test,MAE_test,RMSE_train,MAE_train,noise,outliers]), X_test,Y_test,Y_pred

def LinearRegressionSets(outliers,cols,noise = 0, bias = 0, n_samples = 1000, n_features = 10,n_informative = 2, n_targets = 1,random_state = None, model = LinearRegression):
    coefs_l = []
    metrics_l = []

    outliers_l = np.linspace(0,outliers,5)
    simul_set = outliers_l.shape[0]
    plot_cols = np.clip(cols,1,n_features)
    fig, axes = plt.subplots(simul_set, plot_cols, figsize=(10, 10))
    for i in range(simul_set):
        coef, intercept, metrics, X, Y, Y_pred = LinearRegressionSimul(model=model, 
                                                            outliers= outliers_l[i], 
                                                            noise=noise, 
                                                            bias=bias,
                                                            n_samples=n_samples, 
                                                            n_features= n_features, 
                                                            n_informative=n_informative, 
                                                            n_targets= n_targets, 
                                                            random_state=random_state
                                                            )
        coefs_l.append(coef)
        metrics_l.append(metrics)
        if plot_cols == 1: 
           axes =  np.array(axes).reshape(-1,1)
        for k in range(plot_cols):
            axes[i,k].scatter(X[f'x{k}'],Y)
            axes[i,k].plot(X[f'x{k}'],coef[k]*X[f'x{k}'] + intercept, color='red', linewidth = 3)
            axes[i,k].set(xlabel= f'x{k}', ylabel = 'Target')

    plt.show()

    coefs_l = np.vstack(coefs_l)
    metrics_l = np.vstack(metrics_l)
    df = pd.DataFrame(data=coefs_l,columns=[f'x{i}' for i in range(coefs_l.shape[1])])
    df['RMSE test'] = metrics_l[:,0]
    df['MAE test'] = metrics_l[:,1]
    df['RMSE train'] = metrics_l[:,2]
    df['MAE train'] = metrics_l[:,3]
    df['Outliers'] = metrics_l[:,5]
    return df

df = LinearRegressionSets(10,3,random_state=25, n_features=1, bias = 5)
df.style.format(precision=3, thousands=".", decimal=",")
# Out:
# <style type="text/css">
# </style>
# <table id="T_cadc1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cadc1_level0_col0" class="col_heading level0 col0" >x0</th>
#       <th id="T_cadc1_level0_col1" class="col_heading level0 col1" >RMSE test</th>
#       <th id="T_cadc1_level0_col2" class="col_heading level0 col2" >MAE test</th>
#       <th id="T_cadc1_level0_col3" class="col_heading level0 col3" >RMSE train</th>
#       <th id="T_cadc1_level0_col4" class="col_heading level0 col4" >MAE train</th>
#       <th id="T_cadc1_level0_col5" class="col_heading level0 col5" >Outliers</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cadc1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cadc1_row0_col0" class="data row0 col0" >12,905</td>
#       <td id="T_cadc1_row0_col1" class="data row0 col1" >0,000</td>
#       <td id="T_cadc1_row0_col2" class="data row0 col2" >0,000</td>
#       <td id="T_cadc1_row0_col3" class="data row0 col3" >0,000</td>
#       <td id="T_cadc1_row0_col4" class="data row0 col4" >0,000</td>
#       <td id="T_cadc1_row0_col5" class="data row0 col5" >0,000</td>
#     </tr>
#     <tr>
#       <th id="T_cadc1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cadc1_row1_col0" class="data row1 col0" >-0,070</td>
#       <td id="T_cadc1_row1_col1" class="data row1 col1" >187,921</td>
#       <td id="T_cadc1_row1_col2" class="data row1 col2" >11,187</td>
#       <td id="T_cadc1_row1_col3" class="data row1 col3" >177,653</td>
#       <td id="T_cadc1_row1_col4" class="data row1 col4" >10,442</td>
#       <td id="T_cadc1_row1_col5" class="data row1 col5" >2,500</td>
#     </tr>
#     <tr>
#       <th id="T_cadc1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cadc1_row2_col0" class="data row2 col0" >-0,065</td>
#       <td id="T_cadc1_row2_col1" class="data row2 col1" >187,424</td>
#       <td id="T_cadc1_row2_col2" class="data row2 col2" >11,181</td>
#       <td id="T_cadc1_row2_col3" class="data row2 col3" >177,654</td>
#       <td id="T_cadc1_row2_col4" class="data row2 col4" >10,442</td>
#       <td id="T_cadc1_row2_col5" class="data row2 col5" >5,000</td>
#     </tr>
#     <tr>
#       <th id="T_cadc1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cadc1_row3_col0" class="data row3 col0" >-0,247</td>
#       <td id="T_cadc1_row3_col1" class="data row3 col1" >187,346</td>
#       <td id="T_cadc1_row3_col2" class="data row3 col2" >11,185</td>
#       <td id="T_cadc1_row3_col3" class="data row3 col3" >177,412</td>
#       <td id="T_cadc1_row3_col4" class="data row3 col4" >10,425</td>
#       <td id="T_cadc1_row3_col5" class="data row3 col5" >7,500</td>
#     </tr>
#     <tr>
#       <th id="T_cadc1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cadc1_row4_col0" class="data row4 col0" >0,122</td>
#       <td id="T_cadc1_row4_col1" class="data row4 col1" >188,170</td>
#       <td id="T_cadc1_row4_col2" class="data row4 col2" >11,188</td>
#       <td id="T_cadc1_row4_col3" class="data row4 col3" >177,611</td>
#       <td id="T_cadc1_row4_col4" class="data row4 col4" >10,435</td>
#       <td id="T_cadc1_row4_col5" class="data row4 col5" >10,000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Hacemos un plot para Regresion Linear, con outliers desde 0 al 10%

# %%
df = LinearRegressionSets(1,3,random_state=25, n_features = 1)
df.style.format(precision=3, thousands=".", decimal=",")
# Out:
# <style type="text/css">
# </style>
# <table id="T_d0a5c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d0a5c_level0_col0" class="col_heading level0 col0" >x0</th>
#       <th id="T_d0a5c_level0_col1" class="col_heading level0 col1" >RMSE test</th>
#       <th id="T_d0a5c_level0_col2" class="col_heading level0 col2" >MAE test</th>
#       <th id="T_d0a5c_level0_col3" class="col_heading level0 col3" >RMSE train</th>
#       <th id="T_d0a5c_level0_col4" class="col_heading level0 col4" >MAE train</th>
#       <th id="T_d0a5c_level0_col5" class="col_heading level0 col5" >Outliers</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0a5c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d0a5c_row0_col0" class="data row0 col0" >12,905</td>
#       <td id="T_d0a5c_row0_col1" class="data row0 col1" >0,000</td>
#       <td id="T_d0a5c_row0_col2" class="data row0 col2" >0,000</td>
#       <td id="T_d0a5c_row0_col3" class="data row0 col3" >0,000</td>
#       <td id="T_d0a5c_row0_col4" class="data row0 col4" >0,000</td>
#       <td id="T_d0a5c_row0_col5" class="data row0 col5" >0,000</td>
#     </tr>
#     <tr>
#       <th id="T_d0a5c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d0a5c_row1_col0" class="data row1 col0" >6,026</td>
#       <td id="T_d0a5c_row1_col1" class="data row1 col1" >122,643</td>
#       <td id="T_d0a5c_row1_col2" class="data row1 col2" >8,100</td>
#       <td id="T_d0a5c_row1_col3" class="data row1 col3" >112,491</td>
#       <td id="T_d0a5c_row1_col4" class="data row1 col4" >7,516</td>
#       <td id="T_d0a5c_row1_col5" class="data row1 col5" >0,250</td>
#     </tr>
#     <tr>
#       <th id="T_d0a5c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d0a5c_row2_col0" class="data row2 col0" >3,722</td>
#       <td id="T_d0a5c_row2_col1" class="data row2 col1" >155,814</td>
#       <td id="T_d0a5c_row2_col2" class="data row2 col2" >10,060</td>
#       <td id="T_d0a5c_row2_col3" class="data row2 col3" >147,052</td>
#       <td id="T_d0a5c_row2_col4" class="data row2 col4" >9,224</td>
#       <td id="T_d0a5c_row2_col5" class="data row2 col5" >0,500</td>
#     </tr>
#     <tr>
#       <th id="T_d0a5c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d0a5c_row3_col0" class="data row3 col0" >2,647</td>
#       <td id="T_d0a5c_row3_col1" class="data row3 col1" >182,324</td>
#       <td id="T_d0a5c_row3_col2" class="data row3 col2" >10,549</td>
#       <td id="T_d0a5c_row3_col3" class="data row3 col3" >159,814</td>
#       <td id="T_d0a5c_row3_col4" class="data row3 col4" >9,870</td>
#       <td id="T_d0a5c_row3_col5" class="data row3 col5" >0,750</td>
#     </tr>
#     <tr>
#       <th id="T_d0a5c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d0a5c_row4_col0" class="data row4 col0" >2,009</td>
#       <td id="T_d0a5c_row4_col1" class="data row4 col1" >182,869</td>
#       <td id="T_d0a5c_row4_col2" class="data row4 col2" >11,096</td>
#       <td id="T_d0a5c_row4_col3" class="data row4 col3" >166,380</td>
#       <td id="T_d0a5c_row4_col4" class="data row4 col4" >10,070</td>
#       <td id="T_d0a5c_row4_col5" class="data row4 col5" >1,000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Lo mismo para Ridge

# %%
df = LinearRegressionSets(1,3,random_state=25,model=RidgeCV, n_features = 1)
df.style.format(precision=3, thousands=".", decimal=",")
# Out:
# <style type="text/css">
# </style>
# <table id="T_d91dd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d91dd_level0_col0" class="col_heading level0 col0" >x0</th>
#       <th id="T_d91dd_level0_col1" class="col_heading level0 col1" >RMSE test</th>
#       <th id="T_d91dd_level0_col2" class="col_heading level0 col2" >MAE test</th>
#       <th id="T_d91dd_level0_col3" class="col_heading level0 col3" >RMSE train</th>
#       <th id="T_d91dd_level0_col4" class="col_heading level0 col4" >MAE train</th>
#       <th id="T_d91dd_level0_col5" class="col_heading level0 col5" >Outliers</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d91dd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d91dd_row0_col0" class="data row0 col0" >12,903</td>
#       <td id="T_d91dd_row0_col1" class="data row0 col1" >0,000</td>
#       <td id="T_d91dd_row0_col2" class="data row0 col2" >0,001</td>
#       <td id="T_d91dd_row0_col3" class="data row0 col3" >0,000</td>
#       <td id="T_d91dd_row0_col4" class="data row0 col4" >0,001</td>
#       <td id="T_d91dd_row0_col5" class="data row0 col5" >0,000</td>
#     </tr>
#     <tr>
#       <th id="T_d91dd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d91dd_row1_col0" class="data row1 col0" >6,084</td>
#       <td id="T_d91dd_row1_col1" class="data row1 col1" >85,955</td>
#       <td id="T_d91dd_row1_col2" class="data row1 col2" >6,971</td>
#       <td id="T_d91dd_row1_col3" class="data row1 col3" >117,453</td>
#       <td id="T_d91dd_row1_col4" class="data row1 col4" >7,629</td>
#       <td id="T_d91dd_row1_col5" class="data row1 col5" >0,250</td>
#     </tr>
#     <tr>
#       <th id="T_d91dd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d91dd_row2_col0" class="data row2 col0" >3,044</td>
#       <td id="T_d91dd_row2_col1" class="data row2 col1" >150,868</td>
#       <td id="T_d91dd_row2_col2" class="data row2 col2" >9,676</td>
#       <td id="T_d91dd_row2_col3" class="data row2 col3" >157,096</td>
#       <td id="T_d91dd_row2_col4" class="data row2 col4" >9,593</td>
#       <td id="T_d91dd_row2_col5" class="data row2 col5" >0,500</td>
#     </tr>
#     <tr>
#       <th id="T_d91dd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d91dd_row3_col0" class="data row3 col0" >1,665</td>
#       <td id="T_d91dd_row3_col1" class="data row3 col1" >174,208</td>
#       <td id="T_d91dd_row3_col2" class="data row3 col2" >10,633</td>
#       <td id="T_d91dd_row3_col3" class="data row3 col3" >170,200</td>
#       <td id="T_d91dd_row3_col4" class="data row3 col4" >10,198</td>
#       <td id="T_d91dd_row3_col5" class="data row3 col5" >0,750</td>
#     </tr>
#     <tr>
#       <th id="T_d91dd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d91dd_row4_col0" class="data row4 col0" >2,018</td>
#       <td id="T_d91dd_row4_col1" class="data row4 col1" >182,989</td>
#       <td id="T_d91dd_row4_col2" class="data row4 col2" >11,030</td>
#       <td id="T_d91dd_row4_col3" class="data row4 col3" >166,318</td>
#       <td id="T_d91dd_row4_col4" class="data row4 col4" >10,131</td>
#       <td id="T_d91dd_row4_col5" class="data row4 col5" >1,000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Finalmente para Huber

# %%
df = LinearRegressionSets(1,cols=3,random_state=25,model=HuberRegressor , n_features = 1, bias = 0)
df.style.format(precision=3, thousands=".", decimal=",")
# Out:
# <style type="text/css">
# </style>
# <table id="T_78679">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78679_level0_col0" class="col_heading level0 col0" >x0</th>
#       <th id="T_78679_level0_col1" class="col_heading level0 col1" >RMSE test</th>
#       <th id="T_78679_level0_col2" class="col_heading level0 col2" >MAE test</th>
#       <th id="T_78679_level0_col3" class="col_heading level0 col3" >RMSE train</th>
#       <th id="T_78679_level0_col4" class="col_heading level0 col4" >MAE train</th>
#       <th id="T_78679_level0_col5" class="col_heading level0 col5" >Outliers</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78679_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_78679_row0_col0" class="data row0 col0" >12,905</td>
#       <td id="T_78679_row0_col1" class="data row0 col1" >0,000</td>
#       <td id="T_78679_row0_col2" class="data row0 col2" >0,000</td>
#       <td id="T_78679_row0_col3" class="data row0 col3" >0,000</td>
#       <td id="T_78679_row0_col4" class="data row0 col4" >0,000</td>
#       <td id="T_78679_row0_col5" class="data row0 col5" >0,000</td>
#     </tr>
#     <tr>
#       <th id="T_78679_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_78679_row1_col0" class="data row1 col0" >12,905</td>
#       <td id="T_78679_row1_col1" class="data row1 col1" >165,347</td>
#       <td id="T_78679_row1_col2" class="data row1 col2" >4,694</td>
#       <td id="T_78679_row1_col3" class="data row1 col3" >177,563</td>
#       <td id="T_78679_row1_col4" class="data row1 col4" >5,281</td>
#       <td id="T_78679_row1_col5" class="data row1 col5" >0,250</td>
#     </tr>
#     <tr>
#       <th id="T_78679_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_78679_row2_col0" class="data row2 col0" >5,070</td>
#       <td id="T_78679_row2_col1" class="data row2 col1" >153,585</td>
#       <td id="T_78679_row2_col2" class="data row2 col2" >9,340</td>
#       <td id="T_78679_row2_col3" class="data row2 col3" >152,563</td>
#       <td id="T_78679_row2_col4" class="data row2 col4" >9,181</td>
#       <td id="T_78679_row2_col5" class="data row2 col5" >0,500</td>
#     </tr>
#     <tr>
#       <th id="T_78679_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_78679_row3_col0" class="data row3 col0" >2,940</td>
#       <td id="T_78679_row3_col1" class="data row3 col1" >170,865</td>
#       <td id="T_78679_row3_col2" class="data row3 col2" >10,309</td>
#       <td id="T_78679_row3_col3" class="data row3 col3" >161,856</td>
#       <td id="T_78679_row3_col4" class="data row3 col4" >9,866</td>
#       <td id="T_78679_row3_col5" class="data row3 col5" >0,750</td>
#     </tr>
#     <tr>
#       <th id="T_78679_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_78679_row4_col0" class="data row4 col0" >2,181</td>
#       <td id="T_78679_row4_col1" class="data row4 col1" >179,448</td>
#       <td id="T_78679_row4_col2" class="data row4 col2" >10,847</td>
#       <td id="T_78679_row4_col3" class="data row4 col3" >164,834</td>
#       <td id="T_78679_row4_col4" class="data row4 col4" >10,039</td>
#       <td id="T_78679_row4_col5" class="data row4 col5" >1,000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Usé siempre incrementos de a 5, y noté que apenas pasarte del 1% los outliers rompen la regresión al punto de que todos los parametros parecen prácticamente no informativos. Viendo las gráficas, Huber es el menos susceptible a los outliers, dando un error absoluto medio más bajo que las demás regresiones apenas empiezan a aparecer outliers.

# %% [markdown]
# ## Problema de Clasificación

# %% [markdown]
# ### Ejercicio 6

# %% [markdown]
# En este ejercicio vamos a jugar un poco con descenso de gradiente. Para esto consideremos lo visto en clase que es el problema de regresión.
#
# Como paso inicial, vamos a sacarnos de encima la parte teórica. Recordemos que partimos del siguiente modelo
#
# $$
# y = \beta_0 + \beta_1 \cdot x
# $$
#
# En este caso nuestra función objetivo a optimizar será:
#
# $$
# MSE = ||y-\hat{y}||^2
# $$

# %% [markdown]
# Para calcular el gradiente de la función de error cuadrático medio (MSE) con respecto a los parámetros $\beta_0$ y $\beta_1$, es útil primero expresar la función de coste de forma más explicita. Dado que $\hat{y} = \beta_0 + \beta_1 \cdot x$, podemos reescribir la función MSE como sigue:
#
# $$
# MSE(\beta_0, \beta_1) = \frac{1}{N} \sum_{i=1}^{N} (y_i - \beta_0 - \beta_1 \cdot x_i)^2
# $$
#
# Aquí, $N$ es el número de observaciones en el conjunto de datos y $y_i$ y $x_i$ son el valor observado y el valor de la característica correspondiente para la i-ésima observación.
#
# El gradiente de la función de coste está compuesto por las derivadas parciales de la función de coste con respecto a cada uno de los parámetros. Así, el gradiente es un vector de la forma:
#
# $$
# \nabla MSE(\beta_0, \beta_1) = \left[ \frac{\partial MSE}{\partial \beta_0}, \frac{\partial MSE}{\partial \beta_1} \right]
# $$
#
# Las derivadas parciales se pueden calcular como sigue:
#
# $$
# \frac{\partial MSE}{\partial \beta_0} = \frac{-2}{N} \sum_{i=1}^{N} (y_i - \beta_0 - \beta_1 \cdot x_i)
# $$
#
# $$
# \frac{\partial MSE}{\partial \beta_1} = \frac{-2}{N} \sum_{i=1}^{N} x_i \cdot (y_i - \beta_0 - \beta_1 \cdot x_i)
# $$
#
# Así que finalmente tenemos:
#
# $$
# \nabla MSE(\beta_0, \beta_1) = \left[ \frac{-2}{N} \sum_{i=1}^{N} (y_i - \beta_0 - \beta_1 \cdot x_i), \frac{-2}{N} \sum_{i=1}^{N} x_i \cdot (y_i - \beta_0 - \beta_1 \cdot x_i) \right]
# $$
#
# El cálculo del gradiente se usa en el descenso de gradiente para actualizar los parámetros $\beta_0$ y $\beta_1$ en cada iteración, en dirección opuesta al gradiente, para minimizar la función de coste.
#
# Estos cálculos se pueden implementar en código Python de la siguiente manera:
#
# ```python
# def gradient(X, y, beta0, beta1):
#     N = len(y)
#     y_hat = beta0 + beta1 * X
#
#     d_beta0 = (-2/N) * np.sum(y - y_hat)
#     d_beta1 = (-2/N) * np.sum(X * (y - y_hat))
#
#     return d_beta0, d_beta1
# ```

# %% [markdown]
# Ahora, si quisieramos realizar esto de manera matricial, podemos hacer lo siguiente:
#
# Primero, necesitamos cambiar la representación de nuestros datos. Podemos agregar un vector de unos a nuestra matriz de características para representar el término de intersección $\beta_0$. De esta manera, $X$ toma esta forma:
#
# $$
# X = \begin{bmatrix}
# 1 & x_1 \\
# 1 & x_2 \\
# \vdots & \vdots \\
# 1 & x_N \\
# \end{bmatrix}
# $$
#
# Y nuestro vector de parámetros $\theta$ se verá así:
#
# $$
# \theta = \begin{bmatrix}
# \beta_0 \\
# \beta_1 \\
# \end{bmatrix}
# $$
#
# Entonces, nuestra predicción $\hat{y}$ se calcula como $X\theta$:
#
# $$
# \hat{y} = X\theta = \begin{bmatrix}
# 1 & x_1 \\
# 1 & x_2 \\
# \vdots & \vdots \\
# 1 & x_N \\
# \end{bmatrix} \cdot \begin{bmatrix}
# \beta_0 \\
# \beta_1 \\
# \end{bmatrix}
# $$
#
# Nuestra función de coste MSE se ve de la siguiente manera en forma matricial:
#
# $$
# MSE(\theta) = \frac{1}{N} (y - X\theta)^T (y - X\theta)
# $$
#
# Las derivadas parciales de esta función de coste con respecto a los parámetros se pueden calcular de la siguiente manera:
#
# $$
# \frac{\partial MSE}{\partial \theta} = \frac{-2}{N} X^T (y - X\theta)
# $$

# %% [markdown]
# Esto se puede implementar en Python de la siguiente manera:

# %%
def gradient(X: np.ndarray, y: np.ndarray, theta: np.ndarray) -> np.ndarray:
    """
    Esta función calcula el gradiente de la función de coste del error cuadrático medio (MSE)
    para una regresión lineal simple. La función toma como entrada la matriz de características X,
    el vector de observaciones y y el vector de parámetros theta, y devuelve el gradiente, que
    es un vector de las mismas dimensiones que theta.

    Params:
    X : numpy.ndarray
        La matriz de características extendida que incluye un vector de unos. De tamaño (N, d),
        donde N es el número de observaciones y d es el número de características (incluyendo el
        término de intersección).

    y : numpy.ndarray
        El vector de observaciones. De tamaño (N,), donde N es el número de observaciones.

    theta : numpy.ndarray
        El vector de parámetros. De tamaño (d,), donde d es el número de características
        (incluyendo el término de intersección).

    Returns:
    grad : numpy.ndarray
        El gradiente de la función de coste. Un vector de las mismas dimensiones que theta.

    Examples:
    >>> X = np.array([[1, 1], [1, 2], [1, 3]])
    >>> y = np.array([2, 3, 4])
    >>> theta = np.array([0, 0])
    >>> gradient(X, y, theta)
    array([-4., -8.])
    """
    N = len(y)
    y_hat = X.dot(theta)

    grad = (-2 / N) * X.T.dot(y - y_hat)

    return grad

# %% [markdown]
# Aquí, `X` es la matriz de características extendida que incluye un vector de unos, `y` es el vector de observaciones, y `theta` es el vector de parámetros. La función devuelve el gradiente, que es un vector de las mismas dimensiones que `theta`.

# %% [markdown]
# #### Gradiente Descendente

# %% [markdown]
# Ahora que sabemos calcular el gradiente, vamos a:
#
# 1. Crear una función _GD_ que compute el gradiente descendente. Debe tener condición de frenado
# por nr de épocas pero también por tolerancia.
# 2. Generamos un dataset (con _generate_dataset_ de los ejercicios anteriores, utilizando un bias conocido y solo 1 feature)
# 3. Inicializamos un vector $(\beta_0, \beta_1)$ al azar.
# 4. Tratamos de calcular los mejores parámetros con el algoritmo.
# 5. Guardamos la función de perdida en train y test en cada época.

# %% [markdown]
# Establezco una tolerancia, que es la diferencia entre la perdida entre una interación y la anterior para que se considere convergencia en los parámetros.

# %%
def GD(X, y, lr=0.01, epochs=100, tolerance = 0.01):
    N, d = X.shape
    theta = np.random.randn(d+1) #+1 for the intercept
    X = np.append(np.ones(N).reshape(-1,1),X,axis=1)
    loss_history = []
    last_loss = 0
    for epoch in range(epochs):
        grad = gradient(X, y, theta)
        theta = theta - lr * grad
        loss = np.mean((y - X.dot(theta))**2)
        loss_history.append([epoch,loss])
        if np.abs(last_loss - loss) < tolerance: break
        last_loss = loss
    return theta, np.vstack(loss_history)

# %%
data = generate_dataset(
    n_samples=100,
    n_features=1,
    n_informative=1,
    n_targets=1,
    noise=0,
    bias=0,
    output='dataframe',
    random_state=120
    )
X_train, X_test, Y_train, Y_test = train_test_split(data.drop('target',axis=1),data['target'],train_size=0.8, random_state= 10)
#Hago un grafiquito muy hardcodeado al problema en cuestion (no me juzguen)
theta, loss_history_gd = GD(X_train,Y_train,epochs=200)
X = X_test.values
Y = Y_test.values
plt.scatter(X,Y)
plt.plot(X,theta[1]*X + theta[0], color='red', linewidth = 3)

# %% [markdown]
# #### Gradiente Descendente Estocástico

# %% [markdown]
# Ahora que sabemos calcular el gradiente, vamos a:
#
# 1. Crear una función _SGD_ que compute el gradiente descendente estocástico.
# 2. Generamos un dataset (con _generate_dataset_ de los ejercicios anteriores, utilizando un bias conocido y solo 1 feature)
# 3. Inicializamos un vector $(\beta_0, \beta_1)$ al azar.
# 4. Tratamos de calcular los mejores parámetros con el algoritmo.
# 5. Guardamos la función de perdida en train y test en cada época.

# %%
def SGD(X, y, lr=0.01, epochs=100, batch_size=1, tolerance = 0.01):
    N, d = X.shape
    theta = np.random.randn(d + 1) #+1 for the intercept
    loss_history = []
    X = np.append(np.ones(N).reshape(-1,1),X,axis=1)
    last_loss = 0
    for epoch in range(epochs):
        indices = np.random.permutation(N)
        X = X[indices]
        y = y[indices]

        for i in range(0, N, batch_size):
            X_i = X[i:i+batch_size]
            y_i = y[i:i+batch_size]

            gradient = (-2/batch_size) * X_i.T.dot(y_i - X_i.dot(theta))
            theta = theta - lr * gradient

        loss = np.mean((y - X.dot(theta))**2)
        loss_history.append([epoch,loss])
        if np.abs(last_loss - loss) < tolerance: break
        last_loss = loss
    return theta, np.vstack(loss_history)

# %%
data = generate_dataset(
    n_samples=100,
    n_features=1,
    n_informative=1,
    n_targets=1,
    noise=0,
    bias=0,
    output='dataframe',
    random_state=120
    )

X_train, X_test, Y_train, Y_test = train_test_split(data.drop('target',axis=1),data['target'],train_size=0.8, random_state= 10)
#Hago un grafiquito muy hardcodeado al problema en cuestion (no me juzguen)
theta, loss_history_sgd = SGD(X_train.values,Y_train.values,epochs=200, batch_size=10)
X = X_test.values
Y = Y_test.values
plt.scatter(X,Y)
plt.plot(X,theta[1]*X + theta[0], color='red', linewidth = 3)
print(theta)
# Out:
# [ 0.04908913 37.47389964]

# %% [markdown]
# Analice:
#
# 1. Cómo se comportan estos algoritmos? se puede ver la diferencia entre SGD y GD?.
# 2. Cómo afecto el _learning rate_ a estos algoritmos? Realice una simulación del mismo cambiando el `lr`.
# 3. Compare en una curva de Perdida vs Epoch los dos algoritmos. Nota algo interesante?

# %%
df_gd = pd.DataFrame()
df_gd['Epoch'] = loss_history_gd[:,0]
df_gd['Loss'] = loss_history_gd[:,1]
plt.plot(df_gd['Epoch'], df_gd['Loss'])
plt.show()
df_gd
# Out:
#      Epoch         Loss
# 0      0.0  1074.870048
# 1      1.0  1042.086961
# 2      2.0  1010.318367
# 3      3.0   979.532311
# 4      4.0   949.697863
# ..     ...          ...
# 195  195.0     3.007031
# 196  196.0     2.918995
# 197  197.0     2.833542
# 198  198.0     2.750596
# 199  199.0     2.670083
#
# [200 rows x 2 columns]

# %%
df_sgd = pd.DataFrame()
df_sgd['Epoch'] = loss_history_sgd[:,0]
df_sgd['Loss'] = loss_history_sgd[:,1]
plt.plot(df_sgd['Epoch'], df_sgd['Loss'])
plt.show()
df_sgd
# Out:
#     Epoch        Loss
# 0     0.0  842.836613
# 1     1.0  659.932694
# 2     2.0  517.051606
# 3     3.0  405.334670
# 4     4.0  317.793717
# 5     5.0  249.232896
# 6     6.0  195.701348
# 7     7.0  153.730491
# 8     8.0  120.809977
# 9     9.0   94.939846
# 10   10.0   74.616841
# 11   11.0   58.686450
# 12   12.0   46.169487
# 13   13.0   36.328610
# 14   14.0   28.597650
# 15   15.0   22.511198
# 16   16.0   17.724318
# 17   17.0   13.956108
# 18   18.0   10.994561
# 19   19.0    8.662639
# 20   20.0    6.824852
# 21   21.0    5.375362
# 22   22.0    4.236988
# 23   23.0    3.337731
# 24   24.0    2.630719
# 25   25.0    2.072881
# 26   26.0    1.634451
# 27   27.0    1.288733
# 28   28.0    1.015831
# 29   29.0    0.801154
# 30   30.0    0.631627
# 31   31.0    0.498083
# 32   32.0    0.392892
# 33   33.0    0.309839
# 34   34.0    0.244337
# 35   35.0    0.192712
# 36   36.0    0.152034
# 37   37.0    0.119905
# 38   38.0    0.094575
# 39   39.0    0.074568
# 40   40.0    0.058828
# 41   41.0    0.046409
# 42   42.0    0.036612

# %%
import time
def sgd_sd_comparison(lr = 0.1, epochs = 200):
    data = generate_dataset(
        n_samples=1000,
        n_features=1,
        n_informative=1,
        n_targets=1,
        noise=10,
        bias=0,
        output='dataframe',
        random_state=120
        )

    X_train, X_test, Y_train, Y_test = train_test_split(data.drop('target',axis=1),data['target'],train_size=0.8, random_state= 10)
    #Hago un grafiquito muy hardcodeado al problema en cuestion (no me juzguen)
    X = X_test.values
    Y = Y_test.values
    t0 = time.time_ns()
    theta_gd, loss_history_gd = GD(X_train,Y_train,epochs=epochs, tolerance=0, lr=lr)
    t1 = time.time_ns()
    print("Gradient descent took %g ns "%(t1 - t0))
    t0 = time.time_ns()
    theta_sgd, loss_history_sgd = SGD(X_train.values,Y_train.values,epochs=epochs, batch_size=10, tolerance=0, lr=lr)
    t1 = time.time_ns()
    print("Stochastic Gradient descent took %g ns" %(t1 - t0))
    fig, axes = plt.subplots(1,2,figsize=(20, 5), layout='constrained')
    axes[0].scatter(X,Y)
    axes[0].plot(X,theta_gd[1]*X + theta_gd[0], color='red', linewidth = 2, label='GD', linestyle='--')
    axes[0].plot(X,theta_sgd[1]*X + theta_sgd[0], color='green', linewidth = 2, label='SGD')
    axes[0].legend()
    axes[0].set_title('Optimization comparison')
    axes[0].set_xlabel('x0')
    axes[0].set_ylabel('Prediction')

    df_gd = pd.DataFrame()
    df_gd['Epoch'] = loss_history_gd[:,0]
    df_gd['Loss'] = loss_history_gd[:,1]
    df_sgd = pd.DataFrame()
    df_sgd['Epoch'] = loss_history_sgd[:,0]
    df_sgd['Loss'] = loss_history_sgd[:,1]

    axes[1].plot(df_sgd['Epoch'],df_sgd['Loss'], color='green', linewidth = 2, label='SGD')
    axes[1].plot(df_gd['Epoch'],df_gd['Loss'], color='red', linewidth = 2, label='GD', linestyle='--')
    axes[1].legend()
    axes[1].set_title('Epoch/Loss comparison')
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Loss')

    plt.show()
    return

sgd_sd_comparison(lr = 0.001,epochs=200)
# Out:
# Gradient descent took 2.54993e+07 ns
# Stochastic Gradient descent took 5.30001e+07 ns

# %%
sgd_sd_comparison(lr = 0.01,epochs=200)
# Out:
# Gradient descent took 2.89994e+07 ns
# Stochastic Gradient descent took 5.7502e+07 ns

# %%
sgd_sd_comparison(lr = 0.001,epochs=10)
# Out:
# Gradient descent took 3.4992e+06 ns
# Stochastic Gradient descent took 4.5011e+06 ns

# %% [markdown]
# En conclusión, el descenso gradiente estocástico es veces más rápido que el descenso gradiente a secas, en cuanto a cantidad de iteraciones necesarias. Si se dejan correr la misma cantidad de iteraciones, es decir, estableciendo la tolerancia en 0, el estocástico es ligeramente más lento en procesar (un 50%, aproximadamente).

# %% [markdown]
# ### Ejercicio 7

# %% [markdown]
# TBD
